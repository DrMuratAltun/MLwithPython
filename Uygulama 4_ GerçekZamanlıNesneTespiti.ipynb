# %% [markdown]
# **Yolo 4 ile Web cam üzerinden Nesne Tespiti**
# Bu uygulama, görüntü tabanlı nesne tespiti ve tanıma işlemlerini gerçekleştirmek için Darknet adlı bir derin öğrenme çerçevesini kullanır. Darknet, hızlı ve etkili bir şekilde çalışan bir açık kaynaklı derin öğrenme çerçevesidir.
#
# Uygulama, YOLOv4 (You Only Look Once) adlı bir nesne tespiti yöntemini kullanır. YOLOv4, bir görüntüyü tek bir geçişte analiz ederek nesneleri tespit etme yeteneğine sahiptir ve geleneksel yöntemlere kıyasla daha hızlı bir performans sunar. Bu uygulama, YOLOv4 mimarisine sahip bir ağı kullanarak nesne tespiti ve tanıma yapabilir.
#
# Uygulama, önceden eğitilmiş bir ağırlık dosyasını kullanarak 80 farklı sınıfın (nesnenin) tespitini gerçekleştirebilir. Önceden eğitilmiş ağırlık dosyası, çeşitli nesneleri tespit etmek ve tanımak için eğitilmiş olan derin öğrenme modelinin parametrelerini içerir.
#
# Uygulama, Python programlama dilinde geliştirilmiştir ve OpenCV, NumPy, PIL gibi popüler görüntü işleme kütüphanelerini kullanır. Ayrıca, Darknet çerçevesinin işlevlerini kullanarak nesne tespiti ve tanıma işlemlerini gerçekleştirir.
#
# Bu uygulama, nesne tespiti ve tanıma konularında ilgi duyan araştırmacılar, geliştiriciler ve makine öğrenimi uzmanları için kullanışlı bir araçtır. Aynı zamanda, gerçek zamanlı uygulamalar, güvenlik sistemleri, otomasyon projeleri ve daha birçok alanda kullanılabilecek genel bir amaçlı nesne tespiti aracıdır.
#
#
# Önceden Eğitilmiş bir model kullanıldığı için strandart makine öğrenmesi işlem basamaklarından ayrılmaktadır.

# %% [markdown]
# **Kütüphanelerin kurulması**

# %%
# import dependencies
from IPython.display import display, Javascript, Image
from google.colab.output import eval_js
from google.colab.patches import cv2_imshow
from base64 import b64decode, b64encode
import cv2
import numpy as np
import PIL
import io
import html
import time
import matplotlib.pyplot as plt
# %matplotlib inline
#Bu kod satırı oluşturulan görselleri görmek için her defasında “plt.show()” satırını yazmayı önlüyor

# %% [markdown]
# Bu kod bloğu, görüntü işleme ve gösterme için gerekli olan modülleri içe aktarmak için kullanılır. İlgili modüllerin kısa açıklamaları:
#
# from IPython.display import display, Javascript, Image: IPython ortamında görüntüleri ve JavaScript kodlarını görüntülemek için kullanılan sınıfları içe aktarır.
# from google.colab.output import eval_js: Google Colab çıktılarını değerlendirmek için kullanılan eval_js fonksiyonunu içe aktarır.
# from google.colab.patches import cv2_imshow: Google Colab'da OpenCV kütüphanesi ile görüntüleri göstermek için cv2_imshow fonksiyonunu içe aktarır.
# from base64 import b64decode, b64encode: Base64 kodlama ve çözme işlemleri için kullanılan fonksiyonları içe aktarır.
# import cv2: OpenCV kütüphanesini içe aktarır.
# import numpy as np: NumPy kütüphanesini içe aktarır.
# import PIL: PIL (Python Imaging Library) kütüphanesini içe aktarır.
# import io: Giriş/çıkış işlemleri için io modülünü içe aktarır.
# import html: HTML öğelerinin kodunu dönüştürmek ve işlemek için html modülünü içe aktarır.
# import time: Zaman işlemleri için time modülünü içe aktarır.
# import matplotlib.pyplot as plt: Matplotlib kütüphanesinden pyplot modülünü içe aktarır. %matplotlib inline ifadesi, grafiklerin doğrudan görüntülenmesini sağlar.

# %% [markdown]
# **DarkNet Framework ü kurmak**

# %%
# clone darknet repo
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# fatal: destination path 'darknet' already exists and is not an empty directory.

# %% [markdown]
# !git clone ifadesi, Git'in "clone" komutunu kullanarak bir GitHub deposunu kopyalamak için kullanılır.
# https://github.com/AlexeyAB/darknet ise kopyalanacak depo URL'sini temsil eder. Bu örnekte, "darknet" adlı depo, AlexeyAB kullanıcısının GitHub hesabında bulunmaktadır. <br>Darknet, gerçek zamanlı nesne tespiti ve nesne tanıma için popüler bir açık kaynaklı derin öğrenme çerçevesidir. AlexeyAB tarafından geliştirilen Darknet, C ve CUDA dilinde yazılmıştır ve hızlı ve etkili bir şekilde çalışır.
# <br>
# Darknet, "YOLO" (You Only Look Once) adı verilen bir nesne tespiti yöntemini uygular. YOLO, bir görüntüyü tek bir geçişte analiz ederek nesneleri tespit etme yeteneğine sahiptir. Bu, diğer geleneksel yöntemlere kıyasla daha hızlı bir performans sağlar.

# %% [markdown]
# Dark NEt yapılandırılması

# %%
# change makefile to have GPU, OPENCV and LIBSO enabled
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !sed -i 's/CUDNN_HALF=0/CUDNN_HALF=1/' Makefile
# !sed -i 's/LIBSO=0/LIBSO=1/' Makefile
# Out:
# [Errno 20] Not a directory: 'darknet'
# /content/darknet

# %% [markdown]
# %cd darknet: Bu ifade, çalışma dizinini "darknet" dizinine değiştirir.
#
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile: Bu komut, Makefile dosyasında OPENCV ayarını değiştirir. Önceki değer 0 iken, yeni değer 1 olarak ayarlanır. Bu, OpenCV'nin etkinleştirildiğini belirtir.
#
# !sed -i 's/GPU=0/GPU=1/' Makefile: Bu komut, Makefile dosyasında GPU ayarını değiştirir. GPU değeri 0 iken, yeni değer 1 olarak ayarlanır. Bu, GPU kullanımının etkinleştirildiğini belirtir.
#
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile: Bu komut, Makefile dosyasında CUDNN ayarını değiştirir. CUDNN değeri 0 iken, yeni değer 1 olarak ayarlanır. Bu, CUDNN kütüphanesinin etkinleştirildiğini belirtir.
#
# !sed -i 's/CUDNN_HALF=0/CUDNN_HALF=1/' Makefile: Bu komut, Makefile dosyasında CUDNN_HALF ayarını değiştirir. CUDNN_HALF değeri 0 iken, yeni değer 1 olarak ayarlanır. Bu, yarı hassas hesaplamanın etkinleştirildiğini belirtir.
#
# !sed -i 's/LIBSO=0/LIBSO=1/' Makefile: Bu komut, Makefile dosyasında LIBSO ayarını değiştirir. LIBSO değeri 0 iken, yeni değer 1 olarak ayarlanır. Bu, dinamik kitaplık oluşturmanın etkinleştirildiğini belirtir.
# Bu yapılandırma değişiklikleri, Darknet'i GPU desteği, OpenCV entegrasyonu, CUDNN hızlandırması ve dinamik kitaplık kullanımıyla derlemek için gereklidir. Bu değişiklikler, Darknet'i bu özelliklerle çalışacak şekilde yapılandırır.

# %% [markdown]
# **DArkNet Derleme**

# %%
# make darknet (builds darknet so that you can then use the darknet.py file and have its dependencies)
# !make
# Out:
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -fPIC -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#   946 |                 float rgb[3];
#       |                       ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
# ...

# %% [markdown]
# Makefile, derleme işlemi sırasında gerekli bağımlılıkları ve ayarları yönetir. Bu komut çalıştırıldığında, Darknet derleme işlemi başlar ve derleme süreci tamamlandığında çalışma ortamında kullanıma hazır olur.
#
# Darknet'in derlenmesi, CUDA, OpenCV ve diğer bağımlılıkların doğru şekilde kurulu olduğunu ve yapılandırıldığını varsayar. Derleme işlemi biraz zaman alabilir ve çıktılar derleme işlemi ilerledikçe gösterilecektir.

# %% [markdown]
# **Model Ağrılıklarının İndirilmesi**

# %%
# get bthe scaled yolov4 weights file that is pre-trained to detect 80 classes (objects) from shared google drive
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(
  wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 
  'https://docs.google.com/uc?export=download&id=1V3vsIaxAlGWvK4Aar9bAiK5U0QFttKwq' -O- | sed -rn 
  's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1V3vsIaxAlGWvK4Aar9bAiK5U0QFttKwq" 
  -O yolov4-csp.weights && rm -rf /tmp/cookies.txt

# %% [markdown]
# Bu kod, paylaşılan bir Google Drive üzerinden önceden eğitilmiş olan 80 sınıf (nesne) için ölçeklendirilmiş YOLOv4 ağırlık dosyasını indirir. Bu kodu çalıştırdığınızda, belirtilen önceden eğitilmiş ağırlık dosyası yolov4-csp.weights olarak indirilir ve mevcut çalışma dizininde kaydedilir. Bu ağırlık dosyası, Darknet ile nesne tespiti ve tanıma gibi görevleri gerçekleştirmek için kullanılabilir.

# %% [markdown]
# **Model ağırlıklarının ve girdi boyutlarının ayarlanması**

# %%
from darknet import *
# load in our YOLOv4 architecture network
network, class_names, class_colors = load_network("cfg/yolov4-csp.cfg", "cfg/coco.data", "yolov4-csp.weights")
width = network_width(network)
height = network_height(network)

# %%
# load in our YOLOv4 architecture network
network, class_names, class_colors = load_network("cfg/yolov4-csp.cfg", "cfg/coco.data", "yolov4-csp.weights")
width = network_width(network)
height = network_height(network)

# %% [markdown]
# Bu kod, YOLOv4 mimarisine sahip ağı ağırlık dosyasıyla yükler ve ağın genişlik ve yükseklik değerlerini alır. Bu değerler, giriş görüntülerinin boyutunu ayarlamak için kullanılabilir.

# %% [markdown]
# **Nesne Tespiti İçin Fonksiyon Tanımnlama**

# %%
def darknet_helper(img, width, height):
  darknet_image = make_image(width, height, 3)
  img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  img_resized = cv2.resize(img_rgb, (width, height),
                              interpolation=cv2.INTER_LINEAR)

  # get image ratios to convert bounding boxes to proper size
  img_height, img_width, _ = img.shape
  width_ratio = img_width/width
  height_ratio = img_height/height

  # run model on darknet style image to get detections
  copy_image_from_bytes(darknet_image, img_resized.tobytes())
  detections = detect_image(network, class_names, darknet_image)
  free_image(darknet_image)
  return detections, width_ratio, height_ratio

# %% [markdown]
# Bu işlev, Darknet ağı üzerinde nesne tespiti yapmak için kullanılır. İşlev, giriş görüntüsünü uygun formatta işler, nesne tespiti yapar ve sonuçları döndürür. Ayrıca, sınırlayıcı kutuların orijinal görüntü boyutlarına dönüştürülmesi için oranları da sağlar.

# %% [markdown]
# **Görsel Üzerinde Test Etme**

# %%
# run test on person.jpg image that comes with repository
image = cv2.imread("data/giraffe.jpg")
detections, width_ratio, height_ratio = darknet_helper(image, width, height)

for label, confidence, bbox in detections:
  left, top, right, bottom = bbox2points(bbox)
  left, top, right, bottom = int(left * width_ratio), int(top * height_ratio), int(right * width_ratio), int(bottom * height_ratio)
  cv2.rectangle(image, (left, top), (right, bottom), class_colors[label], 2)
  cv2.putText(image, "{} [{:.2f}]".format(label, float(confidence)),
                    (left, top - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5,
                    class_colors[label], 2)
cv2_imshow(image)

# %% [markdown]
# **Yardımcı Fonksiyonların tanımlanması**

# %%
def js_to_image(js_reply):
  """
  Params:
          js_reply: JavaScript object containing image from webcam
  Returns:
          img: OpenCV BGR image
  """
  # decode base64 image
  image_bytes = b64decode(js_reply.split(',')[1])
  # convert bytes to numpy array
  jpg_as_np = np.frombuffer(image_bytes, dtype=np.uint8)
  # decode numpy array into OpenCV BGR image
  img = cv2.imdecode(jpg_as_np, flags=1)

  return img

# %% [markdown]
# Bu kod, JavaScript nesnesini OpenCV formatında bir görüntüye dönüştürmek için bir işlev tanımlar. İşlevin görevi aşağıdaki adımları gerçekleştirmektir:
#
# js_reply: Webcam'den alınan görüntüyü içeren JavaScript nesnesi.
#
# image_bytes = b64decode(js_reply.split(',')[1]): Base64 kodlu görüntüyü çözerek görüntüyü temsil eden baytları elde eder.
#
# jpg_as_np = np.frombuffer(image_bytes, dtype=np.uint8): Baytları bir NumPy dizisine dönüştürerek görüntüyü temsil eden bir NumPy dizisi oluşturur.
#
# img = cv2.imdecode(jpg_as_np, flags=1): NumPy dizisini OpenCV BGR formatında bir görüntüye dönüştürür.
#
# Son olarak, işlev, dönüştürülen OpenCV BGR görüntüsünü döndürür.
#
# Bu işlev, JavaScript nesnesi olarak alınan görüntüyü OpenCV formatında kullanılabilir hale getirir. Özellikle, bu işlev, web kamerası görüntülerini veya başka bir kaynaktan alınan görüntüleri OpenCV ile işlemek için kullanışlıdır.

# %% [markdown]
# **Video akışında çizim yapmak**

# %%
def bbox_to_bytes(bbox_array):
  """
  Params:
          bbox_array: Numpy array (pixels) containing rectangle to overlay on video stream.
  Returns:
        bytes: Base64 image byte string
  """
  # convert array into PIL image
  bbox_PIL = PIL.Image.fromarray(bbox_array, 'RGBA')
  iobuf = io.BytesIO()
  # format bbox into png for return
  bbox_PIL.save(iobuf, format='png')
  # format return string
  bbox_bytes = 'data:image/png;base64,{}'.format((str(b64encode(iobuf.getvalue()), 'utf-8')))

  return bbox_bytes

# %% [markdown]
# Bu kod, bir dikdörtgenin video akışı üzerinde görselleştirilmesi için bir işlev tanımlar. İşlevin görevi aşağıdaki adımları gerçekleştirmektir:
#
# bbox_array: Video akışı üzerinde yer alacak dikdörtgeni temsil eden bir NumPy dizisi (pikseller).
#
# bbox_PIL = PIL.Image.fromarray(bbox_array, 'RGBA'): NumPy dizisini PIL (Python Imaging Library) görüntüsüne dönüştürür. RGBA renk modunu kullanarak görüntüyü oluşturur.
#
# iobuf = io.BytesIO(): Baytları içeren bir bellek akışı oluşturur.
#
# bbox_PIL.save(iobuf, format='png'): PIL görüntüsünü PNG formatında bellek akışına kaydeder.
#
# bbox_bytes = 'data:image/png;base64,{}'.format((str(b64encode(iobuf.getvalue()), 'utf-8'))): Base64 kodlu görüntüyü bir byte dizisine dönüştürür. Dönüştürülen görüntü, 'data:image/png;base64,' başlığı ile birlikte bir Base64 görüntü byte dizisi olarak temsil edilir.
#
# Son olarak, işlev, Base64 görüntü byte dizisini döndürür.
#
# Bu işlev, dikdörtgenin video akışı üzerinde görselleştirilmesi için kullanılır. Özellikle, bu işlev, nesne tespiti sonuçlarını veya diğer görüntüleme amaçlarını video akışına eklemek için kullanışlıdır.

# %% [markdown]
# ## YOLOv4 on Wecam Images
# Running YOLOv4 on images taken from webcam is fairly straight-forward. We will utilize code within Google Colab's Code Snippets that has a variety of useful code functions to perform various tasks.
#
# We will be using the code snippet for Camera Capture which runs JavaScript code to utilize your computer's webcam. The code snippet will take a webcam photo, which we will then pass into our YOLOv4 model for object detection.
#
# Below is a function to take the webcam picture using JavaScript and then run YOLOv4 on it.

# %% [markdown]
# **Colab üzerinde Web kameradan görüntü  almak**

# %%
def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)

  # get photo data
  data = eval_js('takePhoto({})'.format(quality))
  # get OpenCV format image
  img = js_to_image(data) 
  
  # call our darknet helper on webcam image
  detections, width_ratio, height_ratio = darknet_helper(img, width, height)

  # loop through detections and draw them on webcam image
  for label, confidence, bbox in detections:
    left, top, right, bottom = bbox2points(bbox)
    left, top, right, bottom = int(left * width_ratio), int(top * height_ratio), int(right * width_ratio), int(bottom * height_ratio)
    cv2.rectangle(img, (left, top), (right, bottom), class_colors[label], 2)
    cv2.putText(img, "{} [{:.2f}]".format(label, float(confidence)),
                      (left, top - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5,
                      class_colors[label], 2)
  # save image
  cv2.imwrite(filename, img)

  return filename

# %%
try:
  filename = take_photo('photo.jpg')
  print('Saved to {}'.format(filename))
  
  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))

# %% [markdown]
# **Web Kameradan Canlı Uygulama**

# %%
# JavaScript to properly create our live video stream using our webcam as input
def video_stream():
  js = Javascript('''
    var video;
    var div = null;
    var stream;
    var captureCanvas;
    var imgElement;
    var labelElement;
    
    var pendingResolve = null;
    var shutdown = false;
    
    function removeDom() {
       stream.getVideoTracks()[0].stop();
       video.remove();
       div.remove();
       video = null;
       div = null;
       stream = null;
       imgElement = null;
       captureCanvas = null;
       labelElement = null;
    }
    
    function onAnimationFrame() {
      if (!shutdown) {
        window.requestAnimationFrame(onAnimationFrame);
      }
      if (pendingResolve) {
        var result = "";
        if (!shutdown) {
          captureCanvas.getContext('2d').drawImage(video, 0, 0, 640, 480);
          result = captureCanvas.toDataURL('image/jpeg', 0.8)
        }
        var lp = pendingResolve;
        pendingResolve = null;
        lp(result);
      }
    }
    
    async function createDom() {
      if (div !== null) {
        return stream;
      }

      div = document.createElement('div');
      div.style.border = '2px solid black';
      div.style.padding = '3px';
      div.style.width = '100%';
      div.style.maxWidth = '600px';
      document.body.appendChild(div);
      
      const modelOut = document.createElement('div');
      modelOut.innerHTML = "<span>Durum:</span>";
      labelElement = document.createElement('span');
      labelElement.innerText = 'No data';
      labelElement.style.fontWeight = 'bold';
      modelOut.appendChild(labelElement);
      div.appendChild(modelOut);
           
      video = document.createElement('video');
      video.style.display = 'block';
      video.width = div.clientWidth - 6;
      video.setAttribute('playsinline', '');
      video.onclick = () => { shutdown = true; };
      stream = await navigator.mediaDevices.getUserMedia(
          {video: { facingMode: "environment"}});
      div.appendChild(video);

      imgElement = document.createElement('img');
      imgElement.style.position = 'absolute';
      imgElement.style.zIndex = 1;
      imgElement.onclick = () => { shutdown = true; };
      div.appendChild(imgElement);
      
      const instruction = document.createElement('div');
      instruction.innerHTML = 
          '<span style="color: red; font-weight: bold;">' +
          'When finished, click here or on the video to stop this demo</span>';
      div.appendChild(instruction);
      instruction.onclick = () => { shutdown = true; };
      
      video.srcObject = stream;
      await video.play();

      captureCanvas = document.createElement('canvas');
      captureCanvas.width = 640; //video.videoWidth;
      captureCanvas.height = 480; //video.videoHeight;
      window.requestAnimationFrame(onAnimationFrame);
      
      return stream;
    }
    async function stream_frame(label, imgData) {
      if (shutdown) {
        removeDom();
        shutdown = false;
        return '';
      }

      var preCreate = Date.now();
      stream = await createDom();
      
      var preShow = Date.now();
      if (label != "") {
        labelElement.innerHTML = label;
      }
            
      if (imgData != "") {
        var videoRect = video.getClientRects()[0];
        imgElement.style.top = videoRect.top + "px";
        imgElement.style.left = videoRect.left + "px";
        imgElement.style.width = videoRect.width + "px";
        imgElement.style.height = videoRect.height + "px";
        imgElement.src = imgData;
      }
      
      var preCapture = Date.now();
      var result = await new Promise(function(resolve, reject) {
        pendingResolve = resolve;
      });
      shutdown = false;
      
      return {'create': preShow - preCreate, 
              'show': preCapture - preShow, 
              'capture': Date.now() - preCapture,
              'img': result};
    }
    ''')

  display(js)
  
def video_frame(label, bbox):
  data = eval_js('stream_frame("{}", "{}")'.format(label, bbox))
  return data

# %% [markdown]
# ## Web kameradan Canlı Uygulama

# %%
# start streaming video from webcam
video_stream()
# label for video
label_html = 'Görüntü alınıyor'
# initialze bounding box to empty
bbox = ''
count = 0 
while True:
    js_reply = video_frame(label_html, bbox)
    if not js_reply:
        break

    # convert JS response to OpenCV Image
    frame = js_to_image(js_reply["img"])

    # create transparent overlay for bounding box
    bbox_array = np.zeros([480,640,4], dtype=np.uint8)

    # call our darknet helper on video frame
    detections, width_ratio, height_ratio = darknet_helper(frame, width, height)

    # loop through detections and draw them on transparent overlay image
    for label, confidence, bbox in detections:
      left, top, right, bottom = bbox2points(bbox)
      left, top, right, bottom = int(left * width_ratio), int(top * height_ratio), int(right * width_ratio), int(bottom * height_ratio)
      bbox_array = cv2.rectangle(bbox_array, (left, top), (right, bottom), class_colors[label], 2)
      bbox_array = cv2.putText(bbox_array, "{} [{:.2f}]".format(label, float(confidence)),
                        (left, top - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5,
                        class_colors[label], 2)

    bbox_array[:,:,3] = (bbox_array.max(axis = 2) > 0 ).astype(int) * 255
    # convert overlay of bbox into bytes
    bbox_bytes = bbox_to_bytes(bbox_array)
    # update bbox so next frame gets new overlay
    bbox = bbox_bytes
